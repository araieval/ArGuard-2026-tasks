# %% [markdown]
# # Simple baselines + format checker + scorer
#
# A quick walk-through of the **majority** and **random** baselines for all three subtasks, followed by the **format checker** and the **scorer**. These are the fastest way to produce a valid submission file and to verify the end-to-end pipeline.
#
# **Prerequisite:** `python data/download_data.py` has been run.

# %%
import sys, subprocess
from pathlib import Path

TASK1 = Path.cwd().resolve()
while TASK1.name != 'taskA' and TASK1.parent != TASK1:
    TASK1 = TASK1.parent
DATA = TASK1 / 'data' / 'splits'
PRED = TASK1 / 'predictions'
PRED.mkdir(exist_ok=True)

def sh(*args):
    print('$', ' '.join(args))
    print(subprocess.check_output([sys.executable, *args], text=True, cwd=TASK1))

# %% [markdown]
# ## 1. Majority baseline
#
# Predicts the most-frequent class from the training set on every record.
#
# * Subtask A1: predicts `Not Hateful` (the larger class) for every meme.
# * Subtask A2: predicts the single most-frequent hateful sub-type (`Mocking` on the released data).

# %%
sh('baselines/majority_baseline.py', '--subtask', 'a1',
   '--train', str(DATA / 'train.jsonl'),
   '--target', str(DATA / 'dev_test.jsonl'),
   '--out', str(PRED / 'majority_a1.tsv'),
   '--run-id', 'majority')

sh('baselines/majority_baseline.py', '--subtask', 'a2',
   '--train', str(DATA / 'train.jsonl'),
   '--target', str(DATA / 'dev_test.jsonl'),
   '--out', str(PRED / 'majority_a2.jsonl'))
# Out:
# $ baselines/majority_baseline.py --subtask 1a --train /export/home/alishahrour/Shared_Task/ArGuard-2026-tasks/taskA/data/splits/train.jsonl --target /export/home/alishahrour/Shared_Task/ArGuard-2026-tasks/taskA/data/splits/dev_test.jsonl --out /export/home/alishahrour/Shared_Task/ArGuard-2026-tasks/taskA/predictions/majority_a1.tsv --run-id majority
# INFO loaded train=3500  target=500
# INFO majority class = 'Not Hateful'
# INFO loaded train=3500  target=500
# INFO majority hateful subtype = 'Mocking'
# Wrote /export/home/alishahrour/Shared_Task/ArGuard-2026-tasks/taskA/predictions/majority_a1.tsv
#
# $ baselines/majority_baseline.py --subtask 1b --train /export/home/alishahrour/Shared_Task/ArGuard-2026-tasks/taskA/data/splits/train.jsonl --target /export/home/alishahrour/Shared_Task/ArGuard-2026-tasks/taskA/data/splits/dev_test.jsonl --out /export/home/alishahrour/Shared_Task/ArGuard-2026-tasks/taskA/predictions/majority_a2.jsonl
# Wrote /export/home/alishahrour/Shared_Task/ArGuard-2026-tasks/taskA/predictions/majority_a2.jsonl
# INFO loaded train=3500  target=500
# INFO majority non-hateful subtype = 'Sarcasm'

# %% [markdown]
# ## 2. Random baseline
#
# Bernoulli draw with training-set priors (1A) or independent multi-label draws with per-class priors (1B). Useful as a sanity-check ceiling for trivial systems.

# %%
sh('baselines/random_baseline.py', '--subtask', 'a1',
   '--train', str(DATA / 'train.jsonl'),
   '--target', str(DATA / 'dev_test.jsonl'),
   '--out', str(PRED / 'random_a1.tsv'),
   '--run-id', 'random', '--seed', '42')

sh('baselines/random_baseline.py', '--subtask', 'a2',
   '--train', str(DATA / 'train.jsonl'),
   '--target', str(DATA / 'dev_test.jsonl'),
   '--out', str(PRED / 'random_a2.jsonl'), '--seed', '42')
# Out:
# INFO loaded train=3500  target=500
# INFO p(Hateful) = 0.3783
# $ baselines/random_baseline.py --subtask 1a --train /export/home/alishahrour/Shared_Task/ArGuard-2026-tasks/taskA/data/splits/train.jsonl --target /export/home/alishahrour/Shared_Task/ArGuard-2026-tasks/taskA/data/splits/dev_test.jsonl --out /export/home/alishahrour/Shared_Task/ArGuard-2026-tasks/taskA/predictions/random_a1.tsv --run-id random --seed 42
# Wrote /export/home/alishahrour/Shared_Task/ArGuard-2026-tasks/taskA/predictions/random_a1.tsv
#
# $ baselines/random_baseline.py --subtask 1b --train /export/home/alishahrour/Shared_Task/ArGuard-2026-tasks/taskA/data/splits/train.jsonl --target /export/home/alishahrour/Shared_Task/ArGuard-2026-tasks/taskA/data/splits/dev_test.jsonl --out /export/home/alishahrour/Shared_Task/ArGuard-2026-tasks/taskA/predictions/random_a2.jsonl --seed 42
# Wrote /export/home/alishahrour/Shared_Task/ArGuard-2026-tasks/taskA/predictions/random_a2.jsonl
# INFO loaded train=3500  target=500
# INFO hateful priors = {'Contempt': 0.081, 'Dehumanization': 0.187, 'Exclusion': 0.008, 'Incitement': 0.242, 'Inferiority': 0.043, 'Mocking': 0.533, 'Other': 0.014, 'Slurs': 0.19}
# INFO loaded train=3500  target=500
# INFO non-hateful priors = {'Humor': 0.397, 'Other': 0.175, 'Sarcasm': 0.429}

# %% [markdown]
# ## 3. Format check
#
# Always run the format checker before submitting.

# %%
for subtask, ext in [('a1', 'tsv'), ('a2', 'jsonl')]:
    for kind in ('majority', 'random'):
        sh('format_checker/format_checker.py',
           '--subtask', subtask,
           '--predictions', str(PRED / f'{kind}_{subtask}.{ext}'))
# Out:
# $ format_checker/format_checker.py --subtask 1a --predictions /export/home/alishahrour/Shared_Task/ArGuard-2026-tasks/taskA/predictions/majority_a1.tsv
# OK
#
# $ format_checker/format_checker.py --subtask 1a --predictions /export/home/alishahrour/Shared_Task/ArGuard-2026-tasks/taskA/predictions/random_a1.tsv
# INFO [subtask_a1] OK: 500 predictions, run_id='majority', labels in ['Hateful', 'Not Hateful']
# INFO [subtask_a1] OK: 500 predictions, run_id='random', labels in ['Hateful', 'Not Hateful']
# OK
#
# $ format_checker/format_checker.py --subtask 1b --predictions /export/home/alishahrour/Shared_Task/ArGuard-2026-tasks/taskA/predictions/majority_a2.jsonl
# OK
#
# $ format_checker/format_checker.py --subtask 1b --predictions /export/home/alishahrour/Shared_Task/ArGuard-2026-tasks/taskA/predictions/random_a2.jsonl
# INFO [subtask_a2] OK: 500 predictions, label vocab size=13
# INFO [subtask_a2] OK: 500 predictions, label vocab size=13
# OK

# %% [markdown]
# ## 4. Local scoring against `dev.jsonl`
#
# The dev split is labelled, so we can compute metrics on it locally. (For `dev_test` the leaderboard is the only source of metrics during the development phase.)
#
# We re-run the baselines with `--target dev.jsonl` to align the prediction IDs with the gold IDs.

# %%
sh('baselines/majority_baseline.py', '--subtask', 'a1',
   '--train', str(DATA / 'train.jsonl'), '--target', str(DATA / 'dev.jsonl'),
   '--out', str(PRED / 'majority_a1_dev.tsv'), '--run-id', 'majority_dev')

sh('scorer/scorer.py', '--subtask', 'a1',
   '--gold', str(DATA / 'dev.jsonl'),
   '--predictions', str(PRED / 'majority_a1_dev.tsv'))
# Out:
# $ baselines/majority_baseline.py --subtask 1a --train /export/home/alishahrour/Shared_Task/ArGuard-2026-tasks/taskA/data/splits/train.jsonl --target /export/home/alishahrour/Shared_Task/ArGuard-2026-tasks/taskA/data/splits/dev.jsonl --out /export/home/alishahrour/Shared_Task/ArGuard-2026-tasks/taskA/predictions/majority_a1_dev.tsv --run-id majority_dev
# INFO loaded train=3500  target=500
# INFO majority class = 'Not Hateful'
# Wrote /export/home/alishahrour/Shared_Task/ArGuard-2026-tasks/taskA/predictions/majority_a1_dev.tsv
#
# $ scorer/scorer.py --subtask 1a --gold /export/home/alishahrour/Shared_Task/ArGuard-2026-tasks/taskA/data/splits/dev.jsonl --predictions /export/home/alishahrour/Shared_Task/ArGuard-2026-tasks/taskA/predictions/majority_a1_dev.tsv
# INFO [subtask_a1] OK: 500 predictions, run_id='majority_dev', labels in ['Hateful', 'Not Hateful']
# === subtask_a1: scoring summary ===
# f1_macro          : 0.3835   (official metric)
# accuracy          : 0.6220
# precision_macro   : 0.3110
# recall_macro      : 0.5000
# f1_weighted       : 0.4770
#
# Wrote metrics -> /export/home/alishahrour/Shared_Task/ArGuard-2026-tasks/taskA/predictions/majority_a1_dev.tsv.metrics.json

# %% [markdown]
# Same for Subtask A2:

# %%
for subtask in ('a2',):
    sh('baselines/majority_baseline.py', '--subtask', subtask,
       '--train', str(DATA / 'train.jsonl'), '--target', str(DATA / 'dev.jsonl'),
       '--out', str(PRED / f'majority_{subtask}_dev.jsonl'))
    sh('scorer/scorer.py', '--subtask', subtask,
       '--gold', str(DATA / 'dev.jsonl'),
       '--predictions', str(PRED / f'majority_{subtask}_dev.jsonl'))
# Out:
# $ baselines/majority_baseline.py --subtask 1b --train /export/home/alishahrour/Shared_Task/ArGuard-2026-tasks/taskA/data/splits/train.jsonl --target /export/home/alishahrour/Shared_Task/ArGuard-2026-tasks/taskA/data/splits/dev.jsonl --out /export/home/alishahrour/Shared_Task/ArGuard-2026-tasks/taskA/predictions/majority_a2_dev.jsonl
# Wrote /export/home/alishahrour/Shared_Task/ArGuard-2026-tasks/taskA/predictions/majority_a2_dev.jsonl
#
# $ scorer/scorer.py --subtask 1b --gold /export/home/alishahrour/Shared_Task/ArGuard-2026-tasks/taskA/data/splits/dev.jsonl --predictions /export/home/alishahrour/Shared_Task/ArGuard-2026-tasks/taskA/predictions/majority_a2_dev.jsonl
# INFO loaded train=3500  target=500
# INFO majority hateful subtype = 'Mocking'
# INFO [subtask_a2] OK: 500 predictions, label vocab size=13
# === subtask_a2: scoring summary ===
# f1_macro          : 0.0806   (official metric)
# precision_macro   : 0.0595
# recall_macro      : 0.1250
# f1_weighted       : 0.2208
#
# Wrote metrics -> /export/home/alishahrour/Shared_Task/ArGuard-2026-tasks/taskA/predictions/majority_a2_dev.jsonl.metrics.json
# INFO loaded train=3500  target=500
# INFO majority non-hateful subtype = 'Sarcasm'
# f1_macro          : 0.1922   (official metric)
# precision_macro   : 0.1350
# recall_macro      : 0.3333
# f1_weighted       : 0.2329

# %% [markdown]
# Your baselines should beat these majority numbers \u2014 if not, something is wrong with your training loop.
